# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from pathlib import Path
import numpy as np
import warnings
import os

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

warnings.filterwarnings('ignore')

import sys
from mylib import genomes

# %%
als_root_dir = join(Path.home(), "projects/cp_als/populations")
ftd_root_dir = join(Path.home(), "projects/cp_als/ftd")
cluster_file = "als_population2cluster_AggCluster_k5.csv"

shared_genes = ["VCP", "TBK1", "OPTN", "CCNF", "SQSTM1", "TIA1"]
ftd_gene_names = ["GRN", "MAPT", "CHMP2B"]

models = [
    SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1),
    LinearRegression(),
    RandomForestRegressor(n_estimators=1000, random_state=42, n_jobs=-1),
]

# Create output directories
# csv_output_dir = "data4boxplots"
# plot_output_dir = "plots"
# os.makedirs(csv_output_dir, exist_ok=True)
# os.makedirs(plot_output_dir, exist_ok=True)

# print(f"ALS: {als_root_dir}")
# print(f"FTD: {ftd_root_dir}")
# print(f"Cluster file: {cluster_file}")
# print(f"Shared genes: {shared_genes}")
# print(f"FTD genes: {ftd_gene_names}")
# print(f"Models: {[m.__class__.__name__ for m in models]}")
# print(f"CSV output directory: {csv_output_dir}")
# print(f"Plot output directory: {plot_output_dir}")

# %%
cluster_df = pd.read_csv(cluster_file)
print("Cluster assignments:")
print(cluster_df.head(10))

clusters = {}
for cluster_id in sorted(cluster_df['Cluster'].unique()):
    pops = cluster_df[cluster_df['Cluster'] == cluster_id]['Population'].tolist()
    clusters[cluster_id] = pops
    print(f"\nCluster {cluster_id}: {len(pops)} populations")
    print(f"  {', '.join(pops)}")
# Out:
# Cluster assignments:
#    Index Population  Cluster
# 0      1        ACB        1
# 1      2        ASW        1
# 2      3        BEB        4
# 3      4        CDX        2
# 4      5        CHB        2
# 5      6        CHS        2
# 6      7        CLM        0
# 7      8        ESN        1
# 8      9        FIN        3
# 9     10        GBR        3
#
# Cluster 0: 4 populations
#   CLM, MXL, PEL, PUR
#
# Cluster 1: 7 populations
#   ACB, ASW, ESN, GWD, LWK, MSL, YRI
#
# Cluster 2: 5 populations
#   CDX, CHB, CHS, JPT, KHV
#
# Cluster 3: 4 populations
#   FIN, GBR, IBS, TSI
#
# Cluster 4: 5 populations
#   BEB, GIH, ITU, PJL, STU

# %%
def get_df_list(population_names, data_dir):
    df_list = []
    for population_name in population_names:
        odf = pd.read_csv(join(data_dir, f"output/{population_name}/all.csv"))
        odf = odf[genomes[population_name] + ["gene"]]
        sdf = odf.groupby(['gene']).sum()
        # sdf = odf.groupby(['gene']).mean()
        df_list.append(sdf.transpose())
    return df_list

def get_data_frames(population_names, als_root_dir, ftd_root_dir):
    als_df = pd.concat(get_df_list(population_names, als_root_dir))
    ftd_df = pd.concat(get_df_list(population_names, ftd_root_dir))
    return als_df, ftd_df

def build_model(model, gene_name, shared_genes, merged_train_df, merged_test_df):
    y_train = merged_train_df[[gene_name]].values
    X_train = merged_train_df[shared_genes].values
    y_test = merged_test_df[[gene_name]].values
    X_test = merged_test_df[shared_genes].values
    
    x_scaler = StandardScaler()
    y_scaler = StandardScaler()
    
    X_train_scaled = x_scaler.fit_transform(X_train)
    y_train_scaled = y_scaler.fit_transform(y_train).ravel()
    X_test_scaled = x_scaler.transform(X_test)
    y_test_scaled = y_scaler.transform(y_test).ravel()
    
    model.fit(X_train_scaled, y_train_scaled)
    y_pred_scaled = model.predict(X_test_scaled)
    
    rmse_scaled = np.sqrt(mean_squared_error(y_test_scaled, y_pred_scaled))
    mae_scaled = mean_absolute_error(y_test_scaled, y_pred_scaled)
    
    return {"gene": gene_name, "model": model.__class__.__name__, "rmse": rmse_scaled, "mae": mae_scaled}

# %%
results = []

print(f"\nRunning cluster-based leave-one-out for FTD gene prediction...\n")

for cluster_id, population_names in clusters.items():
    print(f"\n{'='*80}")
    print(f"Cluster {cluster_id}: {len(population_names)} populations")
    print(f"{'='*80}")
    
    for pname in population_names:
        print(f"\nTest population: {pname}")
        testing_population_names = [pname]
        training_population_names = [item for item in population_names if item != pname]
        
        als_train_df, ftd_train_df = get_data_frames(training_population_names, als_root_dir, ftd_root_dir)
        als_test_df, ftd_test_df = get_data_frames(testing_population_names, als_root_dir, ftd_root_dir)
        
        merged_train_df = pd.merge(als_train_df, ftd_train_df, left_index=True, right_index=True)
        merged_test_df = pd.merge(als_test_df, ftd_test_df, left_index=True, right_index=True)
        
        for gene_name in ftd_gene_names:
            for model in models:
                try:
                    res = build_model(model, gene_name, shared_genes, merged_train_df, merged_test_df)
                    res['cluster'] = cluster_id
                    res['test_population'] = pname
                    results.append(res)
                    print(f"  {gene_name} - {model.__class__.__name__}: RMSE={res['rmse']:.4f}, MAE={res['mae']:.4f}")
                except Exception as e:
                    print(f"  {gene_name} - {model.__class__.__name__}: Error - {e}")

results_df = pd.DataFrame(results)
print(f"\n\nTotal experiments: {len(results_df)}")
results_df.head(15)
# Out:
# Running cluster-based leave-one-out for FTD gene prediction...
#
#
# ================================================================================
# Cluster 0: 4 populations
# ================================================================================
#
# Test population: CLM
#   GRN - SVR: RMSE=1.4189, MAE=1.1088
#   GRN - LinearRegression: RMSE=1.0927, MAE=0.8704
#   GRN - RandomForestRegressor: RMSE=1.1106, MAE=0.8641
#   MAPT - SVR: RMSE=1.2928, MAE=1.0685
#   MAPT - LinearRegression: RMSE=1.0645, MAE=0.8850
#   MAPT - RandomForestRegressor: RMSE=1.0704, MAE=0.8979
#   CHMP2B - SVR: RMSE=1.2615, MAE=0.9943
#   CHMP2B - LinearRegression: RMSE=1.0309, MAE=0.8459
#   CHMP2B - RandomForestRegressor: RMSE=1.0384, MAE=0.8607
#
# Test population: MXL
#   GRN - SVR: RMSE=1.3162, MAE=1.0387
#   GRN - LinearRegression: RMSE=1.0160, MAE=0.7578
#   GRN - RandomForestRegressor: RMSE=1.1111, MAE=0.8277
#   MAPT - SVR: RMSE=1.1267, MAE=0.9394
#   MAPT - LinearRegression: RMSE=0.7860, MAE=0.6528
#   MAPT - RandomForestRegressor: RMSE=0.8178, MAE=0.6552
#   CHMP2B - SVR: RMSE=1.2903, MAE=1.0079
#   CHMP2B - LinearRegression: RMSE=0.8498, MAE=0.7519
#   CHMP2B - RandomForestRegressor: RMSE=0.9035, MAE=0.7951
#
# Test population: PEL
#   GRN - SVR: RMSE=1.3147, MAE=0.9814
#   GRN - LinearRegression: RMSE=0.9487, MAE=0.7324
#   GRN - RandomForestRegressor: RMSE=1.0282, MAE=0.7852
#   MAPT - SVR: RMSE=1.1294, MAE=0.8953
#   MAPT - LinearRegression: RMSE=0.8130, MAE=0.6863
#   MAPT - RandomForestRegressor: RMSE=0.8350, MAE=0.7229
#   CHMP2B - SVR: RMSE=1.4547, MAE=1.1366
#   CHMP2B - LinearRegression: RMSE=0.9693, MAE=0.8814
#   CHMP2B - RandomForestRegressor: RMSE=0.9865, MAE=0.8853
#
# Test population: PUR
#   GRN - SVR: RMSE=1.1207, MAE=0.8747
#   GRN - LinearRegression: RMSE=0.9833, MAE=0.7711
#   GRN - RandomForestRegressor: RMSE=1.1081, MAE=0.8683
#   MAPT - SVR: RMSE=1.5807, MAE=1.2455
#   MAPT - LinearRegression: RMSE=1.2933, MAE=1.0744
#   MAPT - RandomForestRegressor: RMSE=1.2958, MAE=1.0794
#   CHMP2B - SVR: RMSE=1.4437, MAE=1.2040
#   CHMP2B - LinearRegression: RMSE=1.1838, MAE=1.0124
#   CHMP2B - RandomForestRegressor: RMSE=1.1889, MAE=1.0102
#
# ================================================================================
# Cluster 1: 7 populations
# ================================================================================
#
# Test population: ACB
#   GRN - SVR: RMSE=1.3579, MAE=1.0659
#   GRN - LinearRegression: RMSE=1.0164, MAE=0.8008
#   GRN - RandomForestRegressor: RMSE=1.0548, MAE=0.8461
#   MAPT - SVR: RMSE=1.4824, MAE=1.1162
#   MAPT - LinearRegression: RMSE=1.2111, MAE=0.9611
#   MAPT - RandomForestRegressor: RMSE=1.2300, MAE=0.9757
#   CHMP2B - SVR: RMSE=1.2514, MAE=1.0340
#   CHMP2B - LinearRegression: RMSE=1.0270, MAE=0.8564
#   CHMP2B - RandomForestRegressor: RMSE=1.0411, MAE=0.8614
#
# Test population: ASW
#   GRN - SVR: RMSE=1.3891, MAE=1.0539
#   GRN - LinearRegression: RMSE=1.3365, MAE=1.0303
#   GRN - RandomForestRegressor: RMSE=1.2709, MAE=1.0099
#   MAPT - SVR: RMSE=1.0978, MAE=0.8544
#   MAPT - LinearRegression: RMSE=1.0179, MAE=0.7958
#   MAPT - RandomForestRegressor: RMSE=1.0144, MAE=0.8021
#   CHMP2B - SVR: RMSE=1.2647, MAE=1.0153
#   CHMP2B - LinearRegression: RMSE=1.0372, MAE=0.8853
#   CHMP2B - RandomForestRegressor: RMSE=1.0417, MAE=0.8621
#
# Test population: ESN
#   GRN - SVR: RMSE=1.2327, MAE=0.9624
#   GRN - LinearRegression: RMSE=0.9148, MAE=0.7675
#   GRN - RandomForestRegressor: RMSE=0.9600, MAE=0.7815
#   MAPT - SVR: RMSE=1.2474, MAE=0.9984
#   MAPT - LinearRegression: RMSE=0.9488, MAE=0.7282
#   MAPT - RandomForestRegressor: RMSE=0.9572, MAE=0.7498
#   CHMP2B - SVR: RMSE=1.4344, MAE=1.1546
#   CHMP2B - LinearRegression: RMSE=1.0820, MAE=0.9316
#   CHMP2B - RandomForestRegressor: RMSE=1.1325, MAE=0.9712
#
# Test population: GWD
#   GRN - SVR: RMSE=1.1434, MAE=0.9198
#   GRN - LinearRegression: RMSE=1.0083, MAE=0.8354
#   GRN - RandomForestRegressor: RMSE=1.0300, MAE=0.8453
#   MAPT - SVR: RMSE=1.3826, MAE=1.0783
#   MAPT - LinearRegression: RMSE=1.0634, MAE=0.8910
#   MAPT - RandomForestRegressor: RMSE=1.0767, MAE=0.8892
#   CHMP2B - SVR: RMSE=1.1420, MAE=0.9052
#   CHMP2B - LinearRegression: RMSE=0.8932, MAE=0.7591
#   CHMP2B - RandomForestRegressor: RMSE=0.9194, MAE=0.7470
#
# Test population: LWK
#   GRN - SVR: RMSE=1.0979, MAE=0.8863
#   GRN - LinearRegression: RMSE=0.9490, MAE=0.7708
#   GRN - RandomForestRegressor: RMSE=0.9566, MAE=0.7753
#   MAPT - SVR: RMSE=1.2371, MAE=0.9732
#   MAPT - LinearRegression: RMSE=0.8900, MAE=0.7193
#   MAPT - RandomForestRegressor: RMSE=1.0151, MAE=0.8252
#   CHMP2B - SVR: RMSE=1.3270, MAE=1.0710
#   CHMP2B - LinearRegression: RMSE=0.9417, MAE=0.7893
#   CHMP2B - RandomForestRegressor: RMSE=0.9916, MAE=0.8148
#
# Test population: MSL
#   GRN - SVR: RMSE=1.1197, MAE=0.8760
#   GRN - LinearRegression: RMSE=1.0034, MAE=0.8243
#   GRN - RandomForestRegressor: RMSE=0.9926, MAE=0.8261
#   MAPT - SVR: RMSE=1.1833, MAE=0.9610
#   MAPT - LinearRegression: RMSE=1.0112, MAE=0.8208
#   MAPT - RandomForestRegressor: RMSE=1.0264, MAE=0.8429
#   CHMP2B - SVR: RMSE=1.3540, MAE=1.0803
#   CHMP2B - LinearRegression: RMSE=1.0196, MAE=0.8527
#   CHMP2B - RandomForestRegressor: RMSE=1.0649, MAE=0.8679
#
# Test population: YRI
#   GRN - SVR: RMSE=1.3078, MAE=1.0250
#   GRN - LinearRegression: RMSE=0.9513, MAE=0.7561
#   GRN - RandomForestRegressor: RMSE=0.9742, MAE=0.7644
#   MAPT - SVR: RMSE=1.2033, MAE=0.9646
#   MAPT - LinearRegression: RMSE=0.9361, MAE=0.7624
#   MAPT - RandomForestRegressor: RMSE=0.9682, MAE=0.7827
#   CHMP2B - SVR: RMSE=1.3204, MAE=1.0977
#   CHMP2B - LinearRegression: RMSE=1.0932, MAE=0.9553
#   CHMP2B - RandomForestRegressor: RMSE=1.1566, MAE=1.0056
#
# ================================================================================
# Cluster 2: 5 populations
# ================================================================================
#
# Test population: CDX
#   GRN - SVR: RMSE=1.1610, MAE=0.9610
#   GRN - LinearRegression: RMSE=1.0446, MAE=0.8634
#   GRN - RandomForestRegressor: RMSE=1.0783, MAE=0.9049
#   MAPT - SVR: RMSE=1.2773, MAE=1.0338
#   MAPT - LinearRegression: RMSE=0.9712, MAE=0.8191
#   MAPT - RandomForestRegressor: RMSE=0.9853, MAE=0.8249
#   CHMP2B - SVR: RMSE=1.1844, MAE=0.9755
#   CHMP2B - LinearRegression: RMSE=0.9335, MAE=0.7783
#   CHMP2B - RandomForestRegressor: RMSE=1.0076, MAE=0.8424
#
# Test population: CHB
#   GRN - SVR: RMSE=1.4322, MAE=1.1404
#   GRN - LinearRegression: RMSE=1.0659, MAE=0.8282
#   GRN - RandomForestRegressor: RMSE=1.1244, MAE=0.8889
#   MAPT - SVR: RMSE=1.6617, MAE=1.3335
#   MAPT - LinearRegression: RMSE=1.0995, MAE=0.9029
#   MAPT - RandomForestRegressor: RMSE=1.1409, MAE=0.9202
#   CHMP2B - SVR: RMSE=1.3924, MAE=1.1148
#   CHMP2B - LinearRegression: RMSE=1.2527, MAE=0.9770
#   CHMP2B - RandomForestRegressor: RMSE=1.2637, MAE=0.9947
#
# Test population: CHS
#   GRN - SVR: RMSE=1.2632, MAE=0.9544
#   GRN - LinearRegression: RMSE=0.9310, MAE=0.7473
#   GRN - RandomForestRegressor: RMSE=0.9818, MAE=0.7866
#   MAPT - SVR: RMSE=1.4693, MAE=1.1656
#   MAPT - LinearRegression: RMSE=0.9697, MAE=0.8350
#   MAPT - RandomForestRegressor: RMSE=1.0073, MAE=0.8701
#   CHMP2B - SVR: RMSE=0.9559, MAE=0.7711
#   CHMP2B - LinearRegression: RMSE=0.8902, MAE=0.6779
#   CHMP2B - RandomForestRegressor: RMSE=0.9271, MAE=0.6557
#
# Test population: JPT
#   GRN - SVR: RMSE=1.1983, MAE=0.9253
#   GRN - LinearRegression: RMSE=1.0593, MAE=0.8133
#   GRN - RandomForestRegressor: RMSE=1.0888, MAE=0.8441
#   MAPT - SVR: RMSE=1.2634, MAE=0.9998
#   MAPT - LinearRegression: RMSE=0.9210, MAE=0.7675
#   MAPT - RandomForestRegressor: RMSE=0.9829, MAE=0.8151
#   CHMP2B - SVR: RMSE=1.3344, MAE=0.9933
#   CHMP2B - LinearRegression: RMSE=1.0150, MAE=0.7794
#   CHMP2B - RandomForestRegressor: RMSE=1.0740, MAE=0.8504
#
# Test population: KHV
#   GRN - SVR: RMSE=1.2127, MAE=1.0104
#   GRN - LinearRegression: RMSE=1.0081, MAE=0.8396
#   GRN - RandomForestRegressor: RMSE=0.9764, MAE=0.8293
#   MAPT - SVR: RMSE=1.2619, MAE=1.0254
#   MAPT - LinearRegression: RMSE=1.0845, MAE=0.9442
#   MAPT - RandomForestRegressor: RMSE=1.1541, MAE=0.9760
#   CHMP2B - SVR: RMSE=1.1056, MAE=0.9009
#   CHMP2B - LinearRegression: RMSE=0.9219, MAE=0.7527
#   CHMP2B - RandomForestRegressor: RMSE=0.9639, MAE=0.7886
#
# ================================================================================
# Cluster 3: 4 populations
# ================================================================================
#
# Test population: FIN
#   GRN - SVR: RMSE=1.2804, MAE=1.0070
#   GRN - LinearRegression: RMSE=0.8946, MAE=0.7384
#   GRN - RandomForestRegressor: RMSE=0.9222, MAE=0.7441
#   MAPT - SVR: RMSE=1.3547, MAE=1.0743
#   MAPT - LinearRegression: RMSE=1.1100, MAE=0.8785
#   MAPT - RandomForestRegressor: RMSE=1.1495, MAE=0.9025
#   CHMP2B - SVR: RMSE=1.4005, MAE=1.0624
#   CHMP2B - LinearRegression: RMSE=1.1215, MAE=0.9195
#   CHMP2B - RandomForestRegressor: RMSE=1.2047, MAE=0.9672
#
# Test population: GBR
#   GRN - SVR: RMSE=1.4936, MAE=1.2293
#   GRN - LinearRegression: RMSE=1.0367, MAE=0.8527
#   GRN - RandomForestRegressor: RMSE=1.0462, MAE=0.8640
#   MAPT - SVR: RMSE=1.3955, MAE=1.0940
#   MAPT - LinearRegression: RMSE=0.9191, MAE=0.7797
#   MAPT - RandomForestRegressor: RMSE=0.9558, MAE=0.7840
#   CHMP2B - SVR: RMSE=1.3641, MAE=1.0634
#   CHMP2B - LinearRegression: RMSE=0.9943, MAE=0.8247
#   CHMP2B - RandomForestRegressor: RMSE=0.9964, MAE=0.8249
#
# Test population: IBS
#   GRN - SVR: RMSE=1.4576, MAE=1.1733
#   GRN - LinearRegression: RMSE=0.9988, MAE=0.8296
#   GRN - RandomForestRegressor: RMSE=1.0577, MAE=0.8994
#   MAPT - SVR: RMSE=1.2886, MAE=1.0831
#   MAPT - LinearRegression: RMSE=1.0602, MAE=0.9143
#   MAPT - RandomForestRegressor: RMSE=1.0984, MAE=0.9456
#   CHMP2B - SVR: RMSE=1.3153, MAE=1.0840
#   CHMP2B - LinearRegression: RMSE=0.8748, MAE=0.7659
#   CHMP2B - RandomForestRegressor: RMSE=0.9301, MAE=0.8017
#
# Test population: TSI
#   GRN - SVR: RMSE=1.4732, MAE=1.1507
#   GRN - LinearRegression: RMSE=1.1181, MAE=0.9083
#   GRN - RandomForestRegressor: RMSE=1.1730, MAE=0.9343
#   MAPT - SVR: RMSE=1.4002, MAE=1.1328
#   MAPT - LinearRegression: RMSE=1.0422, MAE=0.8747
#   MAPT - RandomForestRegressor: RMSE=1.1003, MAE=0.9350
#   CHMP2B - SVR: RMSE=1.2549, MAE=0.9688
#   CHMP2B - LinearRegression: RMSE=1.0281, MAE=0.8822
#   CHMP2B - RandomForestRegressor: RMSE=1.0698, MAE=0.8958
#
# ================================================================================
# Cluster 4: 5 populations
# ================================================================================
#
# Test population: BEB
#   GRN - SVR: RMSE=1.2434, MAE=0.9526
#   GRN - LinearRegression: RMSE=0.9324, MAE=0.7885
#   GRN - RandomForestRegressor: RMSE=1.0101, MAE=0.8536
#   MAPT - SVR: RMSE=1.1384, MAE=0.9405
#   MAPT - LinearRegression: RMSE=0.8528, MAE=0.7123
#   MAPT - RandomForestRegressor: RMSE=0.9111, MAE=0.7522
#   CHMP2B - SVR: RMSE=1.3364, MAE=1.0620
#   CHMP2B - LinearRegression: RMSE=1.0085, MAE=0.8253
#   CHMP2B - RandomForestRegressor: RMSE=1.0307, MAE=0.8243
#
# Test population: GIH
#   GRN - SVR: RMSE=1.4161, MAE=1.0991
#   GRN - LinearRegression: RMSE=1.1123, MAE=0.8842
#   GRN - RandomForestRegressor: RMSE=1.1364, MAE=0.9185
#   MAPT - SVR: RMSE=1.1396, MAE=0.9094
#   MAPT - LinearRegression: RMSE=0.8822, MAE=0.7495
#   MAPT - RandomForestRegressor: RMSE=0.9245, MAE=0.7653
#   CHMP2B - SVR: RMSE=1.3177, MAE=0.9751
#   CHMP2B - LinearRegression: RMSE=0.9488, MAE=0.7511
#   CHMP2B - RandomForestRegressor: RMSE=0.9531, MAE=0.7720
#
# Test population: ITU
#   GRN - SVR: RMSE=1.2214, MAE=0.9688
#   GRN - LinearRegression: RMSE=0.9115, MAE=0.7306
#   GRN - RandomForestRegressor: RMSE=0.9485, MAE=0.7451
#   MAPT - SVR: RMSE=1.3054, MAE=1.0551
#   MAPT - LinearRegression: RMSE=1.0971, MAE=0.9053
#   MAPT - RandomForestRegressor: RMSE=1.0655, MAE=0.8814
#   CHMP2B - SVR: RMSE=1.4905, MAE=1.1199
#   CHMP2B - LinearRegression: RMSE=0.9491, MAE=0.7834
#   CHMP2B - RandomForestRegressor: RMSE=0.9245, MAE=0.7682
#
# Test population: PJL
#   GRN - SVR: RMSE=1.4754, MAE=1.1417
#   GRN - LinearRegression: RMSE=1.0999, MAE=0.8511
#   GRN - RandomForestRegressor: RMSE=1.1779, MAE=0.9148
#   MAPT - SVR: RMSE=1.4555, MAE=1.2157
#   MAPT - LinearRegression: RMSE=1.1622, MAE=0.9796
#   MAPT - RandomForestRegressor: RMSE=1.2178, MAE=1.0276
#   CHMP2B - SVR: RMSE=1.3417, MAE=1.0759
#   CHMP2B - LinearRegression: RMSE=0.9585, MAE=0.8243
#   CHMP2B - RandomForestRegressor: RMSE=1.0068, MAE=0.8508
#
# Test population: STU
#   GRN - SVR: RMSE=1.3404, MAE=1.0433
#   GRN - LinearRegression: RMSE=1.0037, MAE=0.8023
#   GRN - RandomForestRegressor: RMSE=1.0750, MAE=0.8381
#   MAPT - SVR: RMSE=1.3939, MAE=1.0600
#   MAPT - LinearRegression: RMSE=1.0530, MAE=0.8837
#   MAPT - RandomForestRegressor: RMSE=1.0771, MAE=0.8846
#   CHMP2B - SVR: RMSE=1.2402, MAE=0.9794
#   CHMP2B - LinearRegression: RMSE=1.1575, MAE=0.9573
#   CHMP2B - RandomForestRegressor: RMSE=1.2356, MAE=1.0081
#
#
# Total experiments: 225
#       gene                  model      rmse       mae  cluster test_population
# 0      GRN                    SVR  1.418905  1.108806        0             CLM
# 1      GRN       LinearRegression  1.092708  0.870397        0             CLM
# 2      GRN  RandomForestRegressor  1.110624  0.864126        0             CLM
# 3     MAPT                    SVR  1.292798  1.068511        0             CLM
# 4     MAPT       LinearRegression  1.064535  0.884970        0             CLM
# 5     MAPT  RandomForestRegressor  1.070364  0.897872        0             CLM
# 6   CHMP2B                    SVR  1.261533  0.994288        0             CLM
# 7   CHMP2B       LinearRegression  1.030894  0.845903        0             CLM
# 8   CHMP2B  RandomForestRegressor  1.038379  0.860743        0             CLM
# 9      GRN                    SVR  1.316151  1.038704        0             MXL
# 10     GRN       LinearRegression  1.015981  0.757825        0             MXL
# 11     GRN  RandomForestRegressor  1.111134  0.827690        0             MXL
# 12    MAPT                    SVR  1.126745  0.939414        0             MXL
# 13    MAPT       LinearRegression  0.786043  0.652819        0             MXL
# 14    MAPT  RandomForestRegressor  0.817843  0.655214        0             MXL

# %% [markdown]
# ## Visualization: Dot Plots

# %%
# Combined figure: RMSE and MAE subfigures for paper (full page width)
from matplotlib.lines import Line2D
import numpy as np
import matplotlib.pyplot as plt
from os.path import join

_model_colors = {
    "rmse": {
        'LinearRegression': '#000000',
        'RandomForestRegressor': '#009E73',
        'SVR': '#E69F00'
    },
    "mae": {
        'LinearRegression': '#0B1E6B',
        'RandomForestRegressor': '#7CFC00',
        'SVR': '#FF00A8'
    }
}
_model_labels = {
    'LinearRegression': 'Linear Regression',
    'RandomForestRegressor': 'Random Forest',
    'SVR': 'SVR'
}
_models_list = ['LinearRegression', 'RandomForestRegressor', 'SVR']

def _draw_dotplot_ax(ax, results_df, genes_list, metric, model_colors, y_label):
    n_genes = len(genes_list)
    width = 0.25
    global_max = 0.0

    for i, gene in enumerate(genes_list):
        for j, model in enumerate(_models_list):
            data = results_df[
                (results_df['gene'] == gene) &
                (results_df['model'] == model)
            ][metric].values

            if len(data) == 0:
                continue

            mean_val = float(np.mean(data))
            std_val = float(np.std(data, ddof=1)) if len(data) > 1 else 0.0
            n = len(data)
            ci = (1.96 * std_val / np.sqrt(n)) if n > 1 else 0.0
            global_max = max(global_max, mean_val + ci, float(np.max(data)))

            x = i + j * width
            color = model_colors.get(model, '#333333')

            np.random.seed(42 + i * 10 + j)
            x_jitter = x + np.random.normal(0, width * 0.07, size=len(data))

            ax.scatter(x_jitter, data, s=32, alpha=0.85, color=color,
                       edgecolor='black', linewidth=0.4, zorder=3)
            ax.hlines(mean_val, x - width / 3, x + width / 3,
                      colors='black', linewidth=2.0, zorder=4)
            if ci > 0:
                ax.fill_between([x - width / 3, x + width / 3],
                                mean_val - ci, mean_val + ci,
                                color=color, alpha=0.22, zorder=2)

    ax.set_ylabel(y_label, fontsize=11, fontweight='bold')
    gene_centers = [i + width for i in range(n_genes)]
    ax.set_xticks(gene_centers)
    ax.set_xticklabels(genes_list, fontsize=12)
    ax.tick_params(axis='y', labelsize=10)

    legend_elements = [
        Line2D([0], [0], marker='o', linestyle='',
               markerfacecolor=model_colors[m], markeredgecolor='black',
               markersize=6, label=_model_labels[m])
        for m in _models_list
    ]
    ax.legend(handles=legend_elements, loc='upper right', frameon=True, fontsize=10)
    ax.grid(True, alpha=0.25, axis='y')
    if global_max <= 0:
        global_max = 1.0
    ax.set_ylim(0.5, global_max * 1.3)
    ax.set_facecolor("white")


fig, axes = plt.subplots(1, 2, figsize=(13.6, 3.6))
fig.patch.set_facecolor("white")

_draw_dotplot_ax(axes[0], results_df, ftd_gene_names, "rmse",
                 _model_colors["rmse"], "RMSE (Root Mean Square Error)")
_draw_dotplot_ax(axes[1], results_df, ftd_gene_names, "mae",
                 _model_colors["mae"], "MAE (Mean Absolute Error)")


axes[0].set_title("(a) FTD Genes (RMSE)", fontsize=12, fontweight='bold', pad=6)
axes[1].set_title("(b) FTD Genes (MAE)", fontsize=12, fontweight='bold', pad=6)

plt.tight_layout()

# combined_png = join(plot_output_dir, "k5_cluster_ftd_dotplot_combined.png")
# combined_png = join(plot_output_dir, "figure_6.png")
# plt.savefig(combined_png, dpi=300, bbox_inches='tight', facecolor="white")
# print(f"Saved: {combined_png}")
plt.show()
