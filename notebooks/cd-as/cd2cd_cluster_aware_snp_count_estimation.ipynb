# %% [markdown]
# # CP-GEN: Cluste-Aware Genome-level SNP count estimation
#
# **Approach:**
# - Load population clusters from K-Means (k=5)
# - For each cluster, perform leave-one-out validation
# - Train models: Linear Regression, Random Forest, SVR
# - Predict genome-level SNP counts using other genes as features
# - Evaluate with RMSE and MAE

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
from os.path import join
from pathlib import Path
import numpy as np
import warnings

from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error

warnings.filterwarnings('ignore')

# %%
# Import from local modules
import sys

from mylib import genomes

population_dict = {
    "ASW": "African Ancestry, USA",
    "ACB": "African Caribbean, Barbados",
    "BEB": "Bengali, Bangladesh",
    "GBR": "British, England and Scotland",
    "CDX": "Chinese Dai, China",
    "CLM": "Colombian, Colombia",
    "ESN": "Esan, Nigeria",
    "FIN": "Finnish, Finland",
    "GWD": "Gambian Mandinka, Gambia",
    "GIH": "Gujarati Indian, USA",
    "CHB": "Han Beijing, China",
    "CHS": "Han South, China",
    "IBS": "Iberian, Spain",
    "ITU": "Indian Telugu, UK",
    "JPT": "Japanese, Japan",
    "KHV": "Kinh, Vietnam",
    "LWK": "Luhya, Kenya",
    "MSL": "Mende, Sierra Leone",
    "MXL": "Mexican Ancestry, USA",
    "PEL": "Peruvian, Peru",
    "PUR": "Puerto Rican, Puerto Rico",
    "PJL": "Punjabi, Pakistan",
    "STU": "Sri Lankan Tamil, UK",
    "TSI": "Toscani, Italy",
    "YRI": "Yoruba, Nigeria"
}

# %%
# Configuration
root_dir = join(Path.home(),"projects/cp_als/second_pair/")
als_root_dir = join(Path.home(),"projects/cp_als/second_pair/populations/output/CD")
cluster_file = "cd_population2cluster_AggCluster_k5.csv"
target_gene = "IL23R" 

major_genes = ["NOD2", "ATG16L1", "IL23R", "STAT3"]
removed_genes = [g for g in major_genes if g != target_gene]

print(f"data root directory: {root_dir}")
print(f"Cluster file: {cluster_file}")
print(f"Target gene: {target_gene}")
# Out:
# data root directory: /Users/lhvu/projects/cp_als/second_pair/
# Cluster file: cd_population2cluster_AggCluster_k5.csv
# Target gene: IL23R

# %% [markdown]
# ## Load Population Clusters

# %%
# Load cluster assignments
cluster_df = pd.read_csv(cluster_file)
print("Cluster assignments:")
print(cluster_df.head(10))

# Group populations by cluster
clusters = {}
for cluster_id in sorted(cluster_df['Cluster'].unique()):
    pops = cluster_df[cluster_df['Cluster'] == cluster_id]['Population'].tolist()
    clusters[cluster_id] = pops
    print(f"\nCluster {cluster_id}: {len(pops)} populations")
    print(f"  {', '.join(pops)}")
# Out:
# Cluster assignments:
#    Index Population  Cluster
# 0      1        ACB        3
# 1      2        ASW        3
# 2      3        BEB        1
# 3      4        CDX        2
# 4      5        CHB        2
# 5      6        CHS        2
# 6      7        CLM        0
# 7      8        ESN        3
# 8      9        FIN        4
# 9     10        GBR        4
#
# Cluster 0: 4 populations
#   CLM, MXL, PEL, PUR
#
# Cluster 1: 5 populations
#   BEB, GIH, ITU, PJL, STU
#
# Cluster 2: 5 populations
#   CDX, CHB, CHS, JPT, KHV
#
# Cluster 3: 7 populations
#   ACB, ASW, ESN, GWD, LWK, MSL, YRI
#
# Cluster 4: 4 populations
#   FIN, GBR, IBS, TSI

# %% [markdown]
# ## Helper Functions

# %%
def get_df_list(population_names, data_dir):
    """Load data for multiple populations"""
    als_df_list = list()
    for population_name in population_names:
        odf = pd.read_csv(join(data_dir, f"{population_name}/all.csv"))
        odf = odf[genomes[population_name] + ["gene"]]
        sdf = odf.groupby(['gene']).sum()
        # sdf = odf.groupby(['gene']).mean()
        als_df_list.append(sdf.transpose())
    return als_df_list

def get_als_data_frames(population_names, als_root_dir):
    """Concatenate data frames for multiple populations"""
    als_df = pd.concat(get_df_list(
        population_names=population_names,
        data_dir=als_root_dir,
    ))
    return als_df

def build_model_als(model, gene_name, remaining_genes, train_df, test_df):
    """Train and evaluate a model for a specific gene"""
    y_train = train_df[[gene_name]].values
    X_train = train_df[remaining_genes].values
    y_test = test_df[[gene_name]].values
    X_test = test_df[remaining_genes].values
    
    # Fit scalers only on training data
    x_scaler = StandardScaler()
    y_scaler = StandardScaler()
    
    X_train_scaled = x_scaler.fit_transform(X_train)
    y_train_scaled = y_scaler.fit_transform(y_train).ravel()

    # Apply same transform to test data
    X_test_scaled = x_scaler.transform(X_test)
    y_test_scaled = y_scaler.transform(y_test).ravel()

    model.fit(X_train_scaled, y_train_scaled)
    y_pred_scaled = model.predict(X_test_scaled)

    # Compute metrics in scaled space
    rmse_scaled = np.sqrt(mean_squared_error(y_test_scaled, y_pred_scaled))
    mae_scaled = mean_absolute_error(y_test_scaled, y_pred_scaled)

    res = {
        "gene": gene_name,
        "model": model.__class__.__name__,
        "rmse": rmse_scaled,
        "mae": mae_scaled
    }
    
    return res

# %%
# Define cluster labels
cluster_labels = {
    0: 'American (4 pops)',
    1: 'African (7 pops)',
    2: 'East Asian (5 pops)',
    3: 'European (4 pops)',
    4: 'South Asian (5 pops)'
}

# %% [markdown]
# ## Machine Learning

# %%
# Define models
models = [
    LinearRegression(),
    RandomForestRegressor(n_estimators=1000, random_state=42, n_jobs=-1),
    SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.1),
]

print(f"Models to test: {[m.__class__.__name__ for m in models]}")
# Out:
# Models to test: ['LinearRegression', 'RandomForestRegressor', 'SVR']

# %%
# Store results
results = []

print(f"\nRunning cluster-based leave-one-out for {target_gene}...\n")

# For each cluster
for cluster_id, population_names in clusters.items():
    print(f"\n{'='*80}")
    print(f"Cluster {cluster_id}: {len(population_names)} populations")
    print(f"{'='*80}")
    
    # For each population in the cluster (leave-one-out)
    for pname in population_names:
        print(f"\nTest population: {pname} ({population_dict[pname]})")
        
        # Define train and test populations
        testing_population_names = [pname]
        training_population_names = [item for item in population_names if item != pname]
        
        # Load data
        als_train_df = get_als_data_frames(
            population_names=training_population_names,
            als_root_dir=als_root_dir,
        )
        als_test_df = get_als_data_frames(
            population_names=testing_population_names,
            als_root_dir=als_root_dir,
        )
        
        # Get gene names
        gene_name = target_gene
        remaining_genes = [g for g in list(als_train_df.columns) if g != gene_name and g not in removed_genes]
        print(f"number of genes: {len(remaining_genes)}")
        print(remaining_genes, target_gene)
        
        # Train and evaluate each model
        for model in models:
            try:
                res = build_model_als(model, gene_name, remaining_genes, 
                                     als_train_df, als_test_df)
                res['cluster'] = cluster_id
                res['test_population'] = pname
                results.append(res)
                
                print(f"  {model.__class__.__name__}: RMSE={res['rmse']:.4f}, MAE={res['mae']:.4f}")
            except Exception as e:
                print(f"  {model.__class__.__name__}: Error - {e}")

# Convert to DataFrame
results_df = pd.DataFrame(results)
print(f"\n\nTotal experiments: {len(results_df)}")
results_df.head(10)
# Out:
# Running cluster-based leave-one-out for IL23R...
#
#
# ================================================================================
# Cluster 0: 4 populations
# ================================================================================
#
# Test population: CLM (Colombian, Colombia)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0635, MAE=0.8791
#   RandomForestRegressor: RMSE=1.0267, MAE=0.8377
#   SVR: RMSE=1.0162, MAE=0.8410
#
# Test population: MXL (Mexican Ancestry, USA)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.2473, MAE=0.9319
#   RandomForestRegressor: RMSE=1.2203, MAE=0.9527
#   SVR: RMSE=1.1690, MAE=0.8946
#
# Test population: PEL (Peruvian, Peru)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.7578, MAE=0.6049
#   RandomForestRegressor: RMSE=0.7919, MAE=0.6290
#   SVR: RMSE=0.7738, MAE=0.6290
#
# Test population: PUR (Puerto Rican, Puerto Rico)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.2163, MAE=1.0019
#   RandomForestRegressor: RMSE=1.1855, MAE=0.9699
#   SVR: RMSE=1.1366, MAE=0.9229
#
# ================================================================================
# Cluster 1: 5 populations
# ================================================================================
#
# Test population: BEB (Bengali, Bangladesh)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0526, MAE=0.9595
#   RandomForestRegressor: RMSE=1.0483, MAE=0.9612
#   SVR: RMSE=1.0260, MAE=0.9265
#
# Test population: GIH (Gujarati Indian, USA)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0553, MAE=0.9682
#   RandomForestRegressor: RMSE=1.0505, MAE=0.9600
#   SVR: RMSE=1.0263, MAE=0.9357
#
# Test population: ITU (Indian Telugu, UK)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.9755, MAE=0.8650
#   RandomForestRegressor: RMSE=0.9575, MAE=0.8581
#   SVR: RMSE=0.9918, MAE=0.8661
#
# Test population: PJL (Punjabi, Pakistan)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0359, MAE=0.9101
#   RandomForestRegressor: RMSE=1.0088, MAE=0.8981
#   SVR: RMSE=1.0190, MAE=0.8991
#
# Test population: STU (Sri Lankan Tamil, UK)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0641, MAE=0.9401
#   RandomForestRegressor: RMSE=1.0358, MAE=0.9234
#   SVR: RMSE=1.0303, MAE=0.9153
#
# ================================================================================
# Cluster 2: 5 populations
# ================================================================================
#
# Test population: CDX (Chinese Dai, China)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.1030, MAE=0.9931
#   RandomForestRegressor: RMSE=1.0609, MAE=0.9666
#   SVR: RMSE=1.0681, MAE=0.9428
#
# Test population: CHB (Han Beijing, China)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.9568, MAE=0.8225
#   RandomForestRegressor: RMSE=0.9297, MAE=0.7981
#   SVR: RMSE=0.9523, MAE=0.8177
#
# Test population: CHS (Han South, China)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0021, MAE=0.8690
#   RandomForestRegressor: RMSE=0.9916, MAE=0.8475
#   SVR: RMSE=1.0083, MAE=0.8452
#
# Test population: JPT (Japanese, Japan)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.1563, MAE=1.0261
#   RandomForestRegressor: RMSE=1.1161, MAE=0.9951
#   SVR: RMSE=1.1433, MAE=1.0180
#
# Test population: KHV (Kinh, Vietnam)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0192, MAE=0.8920
#   RandomForestRegressor: RMSE=1.0017, MAE=0.8876
#   SVR: RMSE=1.0060, MAE=0.8728
#
# ================================================================================
# Cluster 3: 7 populations
# ================================================================================
#
# Test population: ACB (African Caribbean, Barbados)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.2642, MAE=1.0166
#   RandomForestRegressor: RMSE=1.2248, MAE=1.0049
#   SVR: RMSE=1.2378, MAE=1.0138
#
# Test population: ASW (African Ancestry, USA)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0541, MAE=0.8596
#   RandomForestRegressor: RMSE=1.0492, MAE=0.8537
#   SVR: RMSE=1.0614, MAE=0.8580
#
# Test population: ESN (Esan, Nigeria)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.9395, MAE=0.7744
#   RandomForestRegressor: RMSE=0.9155, MAE=0.7347
#   SVR: RMSE=0.9369, MAE=0.7561
#
# Test population: GWD (Gambian Mandinka, Gambia)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.9517, MAE=0.8192
#   RandomForestRegressor: RMSE=0.9769, MAE=0.8368
#   SVR: RMSE=1.0052, MAE=0.8578
#
# Test population: LWK (Luhya, Kenya)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.8527, MAE=0.7015
#   RandomForestRegressor: RMSE=0.8278, MAE=0.6697
#   SVR: RMSE=0.8377, MAE=0.6718
#
# Test population: MSL (Mende, Sierra Leone)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0732, MAE=0.8936
#   RandomForestRegressor: RMSE=1.1091, MAE=0.9233
#   SVR: RMSE=1.1113, MAE=0.9159
#
# Test population: YRI (Yoruba, Nigeria)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0499, MAE=0.8287
#   RandomForestRegressor: RMSE=1.0599, MAE=0.8337
#   SVR: RMSE=1.0415, MAE=0.8238
#
# ================================================================================
# Cluster 4: 4 populations
# ================================================================================
#
# Test population: FIN (Finnish, Finland)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.2356, MAE=0.9671
#   RandomForestRegressor: RMSE=1.1586, MAE=0.8856
#   SVR: RMSE=1.1657, MAE=0.8923
#
# Test population: GBR (British, England and Scotland)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=0.9208, MAE=0.7473
#   RandomForestRegressor: RMSE=0.9356, MAE=0.7431
#   SVR: RMSE=0.9289, MAE=0.7352
#
# Test population: IBS (Iberian, Spain)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0282, MAE=0.8301
#   RandomForestRegressor: RMSE=1.0019, MAE=0.8363
#   SVR: RMSE=1.0191, MAE=0.8249
#
# Test population: TSI (Toscani, Italy)
# number of genes: 25
# ['ABCB1', 'ATG4C', 'CARD9', 'CDKAL1', 'DLG5', 'GPR35', 'HLA-DRB1', 'IL10', 'IL10RA', 'IL10RB', 'IL12B', 'IRF5', 'JAK2', 'KIF21B', 'LRRK2', 'MST1', 'NKX2-3', 'PTPN2', 'PTPN22', 'SLC22A4', 'SLC22A5', 'TLR4', 'TNF', 'TNFSF15', 'ZMIZ1'] IL23R
#   LinearRegression: RMSE=1.0589, MAE=0.8368
#   RandomForestRegressor: RMSE=1.0314, MAE=0.8045
#   SVR: RMSE=1.0384, MAE=0.8153
#
#
# Total experiments: 75
#     gene                  model      rmse       mae  cluster test_population
# 0  IL23R       LinearRegression  1.063478  0.879069        0             CLM
# 1  IL23R  RandomForestRegressor  1.026653  0.837666        0             CLM
# 2  IL23R                    SVR  1.016176  0.840976        0             CLM
# 3  IL23R       LinearRegression  1.247290  0.931942        0             MXL
# 4  IL23R  RandomForestRegressor  1.220286  0.952714        0             MXL
# 5  IL23R                    SVR  1.169002  0.894614        0             MXL
# 6  IL23R       LinearRegression  0.757834  0.604942        0             PEL
# 7  IL23R  RandomForestRegressor  0.791924  0.629035        0             PEL
# 8  IL23R                    SVR  0.773807  0.629009        0             PEL
# 9  IL23R       LinearRegression  1.216319  1.001881        0             PUR

# %%
# Save detailed results
# results_df.to_csv(f'k5_cluster_{target_gene}_prediction_detailed.csv', index=False)
# print(f"Detailed results saved to: k5_cluster_{target_gene}_prediction_detailed.csv")

# Calculate summary statistics by cluster and model
summary_df = results_df.groupby(['cluster', 'model']).agg({
    'rmse': ['mean', 'std'],
    'mae': ['mean', 'std']
}).reset_index()

summary_df.columns = ['cluster', 'model', 'rmse_mean', 'rmse_std', 'mae_mean', 'mae_std']
# summary_df.to_csv(f'k5_cluster_{target_gene}_prediction_summary.csv', index=False)
# print(f"Summary results saved to: k5_cluster_{target_gene}_prediction_summary.csv")

print("\nSummary:")
print(summary_df)
# Out:
# Summary:
#     cluster                  model  rmse_mean  rmse_std  mae_mean   mae_std
# 0         0       LinearRegression   1.071230  0.223849  0.854459  0.173783
# 1         0  RandomForestRegressor   1.056103  0.195252  0.847338  0.156934
# 2         0                    SVR   1.023902  0.179228  0.821885  0.133000
# 3         1       LinearRegression   1.036714  0.035692  0.928601  0.041951
# 4         1  RandomForestRegressor   1.020161  0.038771  0.920181  0.043640
# 5         1                    SVR   1.018673  0.015584  0.908549  0.027368
# 6         2       LinearRegression   1.047484  0.080629  0.920540  0.085847
# 7         2  RandomForestRegressor   1.019991  0.071080  0.898955  0.081793
# 8         2                    SVR   1.035602  0.072844  0.899297  0.081025
# 9         3       LinearRegression   1.026488  0.131258  0.841938  0.098697
# 10        3  RandomForestRegressor   1.023329  0.130351  0.836678  0.111358
# 11        3                    SVR   1.033124  0.127228  0.842433  0.109669
# 12        4       LinearRegression   1.060878  0.130657  0.845325  0.090802
# 13        4  RandomForestRegressor   1.031897  0.093503  0.817356  0.059701
# 14        4                    SVR   1.038021  0.097586  0.816914  0.064373

# %% [markdown]
# ## Visualization

# %%
# Plot RMSE with Distribution (Dot Plot + Mean + CI)
fig, ax = plt.subplots(figsize=(14, 7))

# Color scheme for RMSE plot
rmse_colors = {'LinearRegression': '#1f77b4', 'RandomForestRegressor': '#ff7f0e', 'SVR': '#2ca02c'}
model_labels = {'LinearRegression': 'LR', 'RandomForestRegressor': 'RF', 'SVR': 'SVR'}

model_names = results_df['model'].unique()
clusters_sorted = sorted(clusters.keys())
n_clusters = len(clusters_sorted)
n_models = len(model_names)
width = 0.25

# Plot for each cluster and model
for i, cluster_id in enumerate(clusters_sorted):
    for j, model in enumerate(model_names):
        # Get all RMSE values for this cluster and model
        data = results_df[(results_df['cluster'] == cluster_id) & 
                         (results_df['model'] == model)]['rmse'].values
        
        # Calculate statistics
        mean_val = np.mean(data)
        std_val = np.std(data)
        n = len(data)
        # 95% confidence interval
        ci = 1.96 * std_val / np.sqrt(n)
        
        # Position
        x = i + j * width
        color = rmse_colors.get(model, '#333333')
        
        # Add jitter to x for individual points
        np.random.seed(42 + i * 10 + j)  # Reproducible jitter
        x_jitter = x + np.random.normal(0, width * 0.08, size=len(data))
        
        # Plot individual fold results as dots
        ax.scatter(x_jitter, data, s=80, alpha=0.6, color=color, zorder=3)
        
        # Plot mean line
        ax.hlines(mean_val, x - width/3, x + width/3, colors=color, linewidth=3, zorder=4)
        
        # Plot shaded CI region
        ax.fill_between([x - width/3, x + width/3], mean_val - ci, mean_val + ci, 
                         color=color, alpha=0.2, zorder=2)

# Set labels and formatting
ax.set_ylabel('RMSE', fontsize=12, fontweight='bold')
ax.set_title(f'{target_gene} Prediction: RMSE Distribution by Cluster and Model\n(Dots = individual folds, line = mean, shaded = 95% CI)', 
             fontsize=14, fontweight='bold')

# Set x-axis ticks at cluster centers
cluster_centers = [i + width for i in range(n_clusters)]
ax.set_xticks(cluster_centers)
ax.set_xticklabels([cluster_labels[c] for c in clusters_sorted], fontsize=10)

# Create custom legend
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=rmse_colors[model], alpha=0.6, 
                         edgecolor='black', label=model_labels[model]) 
                  for model in model_names]
ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1), 
          frameon=True, shadow=True, fontsize=11)

ax.grid(True, alpha=0.3, axis='y')
ax.set_ylim(bottom=0)

plt.tight_layout()
# plt.savefig(f'k5_cluster_{target_gene}_rmse_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"RMSE distribution plot saved as: k5_cluster_{target_gene}_rmse_distribution.png")
# Out:
# RMSE distribution plot saved as: k5_cluster_IL23R_rmse_distribution.png

# %%
# Plot MAE with Distribution (Dot Plot + Mean + CI)
fig, ax = plt.subplots(figsize=(14, 7))

# Different color scheme for MAE plot
mae_colors = {'LinearRegression': '#d62728', 'RandomForestRegressor': '#9467bd', 'SVR': '#8c564b'}
model_labels = {'LinearRegression': 'LR', 'RandomForestRegressor': 'RF', 'SVR': 'SVR'}

model_names = results_df['model'].unique()
clusters_sorted = sorted(clusters.keys())
n_clusters = len(clusters_sorted)
n_models = len(model_names)
width = 0.25

# Plot for each cluster and model
for i, cluster_id in enumerate(clusters_sorted):
    for j, model in enumerate(model_names):
        # Get all MAE values for this cluster and model
        data = results_df[(results_df['cluster'] == cluster_id) & 
                         (results_df['model'] == model)]['mae'].values
        
        # Calculate statistics
        mean_val = np.mean(data)
        std_val = np.std(data)
        n = len(data)
        # 95% confidence interval
        ci = 1.96 * std_val / np.sqrt(n)
        
        # Position
        x = i + j * width
        color = mae_colors.get(model, '#333333')
        
        # Add jitter to x for individual points
        np.random.seed(42 + i * 10 + j)  # Reproducible jitter
        x_jitter = x + np.random.normal(0, width * 0.08, size=len(data))
        
        # Plot individual fold results as dots
        ax.scatter(x_jitter, data, s=80, alpha=0.6, color=color, zorder=3)
        
        # Plot mean line
        ax.hlines(mean_val, x - width/3, x + width/3, colors=color, linewidth=3, zorder=4)
        
        # Plot shaded CI region
        ax.fill_between([x - width/3, x + width/3], mean_val - ci, mean_val + ci, 
                         color=color, alpha=0.2, zorder=2)

# Set labels and formatting
ax.set_ylabel('MAE', fontsize=12, fontweight='bold')
ax.set_title(f'{target_gene} Prediction: MAE Distribution by Cluster and Model\n(Dots = individual folds, line = mean, shaded = 95% CI)', 
             fontsize=14, fontweight='bold')

# Set x-axis ticks at cluster centers
cluster_centers = [i + width for i in range(n_clusters)]
ax.set_xticks(cluster_centers)
ax.set_xticklabels([cluster_labels[c] for c in clusters_sorted], fontsize=10)

# Create custom legend
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor=mae_colors[model], alpha=0.6, 
                         edgecolor='black', label=model_labels[model]) 
                  for model in model_names]
ax.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1.02, 1), 
          frameon=True, shadow=True, fontsize=11)

ax.grid(True, alpha=0.3, axis='y')
ax.set_ylim(bottom=0)

plt.tight_layout()
# plt.savefig(f'k5_cluster_{target_gene}_mae_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

print(f"MAE distribution plot saved as: k5_cluster_{target_gene}_mae_distribution.png")
# Out:
# MAE distribution plot saved as: k5_cluster_IL23R_mae_distribution.png

# %% [markdown]
# # Save Data for Figure 9

# %%
import os

# Create data4boxplots directory if it doesn't exist
output_dir = 'data4boxplots'
os.makedirs(output_dir, exist_ok=True)

# Prepare data for leave-one-population-out (within cluster) approach
# This approach trains on all populations in a cluster except one, tests on the left-out population
lopo_data = results_df[['gene', 'model', 'rmse', 'mae', 'cluster', 'test_population']].copy()
lopo_data['approach'] = 'CP-ALS(k=5)'
lopo_data['pair'] = lopo_data['test_population']  # Use test population as identifier

# Save the data with consistent structure for later comparison
output_file = os.path.join(output_dir, f'k5_cluster_{target_gene}_cpals_data_dotplot.csv')
lopo_data.to_csv(output_file, index=False)
print(f"CP-ALS(k=5) data saved to: {output_file}")
print(f"  Rows: {len(lopo_data)}")
print(f"  Columns: {list(lopo_data.columns)}")

# Display sample of data
print("\nSample of data:")
print(lopo_data.head(10))

# Display summary statistics
print("\nData summary by cluster and model:")
summary = lopo_data.groupby(['cluster', 'model']).agg({
    'rmse': ['count', 'mean', 'std'],
    'mae': ['mean', 'std']
}).round(3)
print(summary)

print("\nOverall summary by model:")
overall_summary = lopo_data.groupby('model').agg({
    'rmse': ['count', 'mean', 'std'],
    'mae': ['mean', 'std']
}).round(3)
print(overall_summary)
# Out:
# CP-ALS(k=5) data saved to: data4boxplots/k5_cluster_IL23R_cpals_data_dotplot.csv
#   Rows: 75
#   Columns: ['gene', 'model', 'rmse', 'mae', 'cluster', 'test_population', 'approach', 'pair']
#
# Sample of data:
#     gene                  model      rmse       mae  cluster test_population  \
# 0  IL23R       LinearRegression  1.063478  0.879069        0             CLM
# 1  IL23R  RandomForestRegressor  1.026653  0.837666        0             CLM
# 2  IL23R                    SVR  1.016176  0.840976        0             CLM
# 3  IL23R       LinearRegression  1.247290  0.931942        0             MXL
# 4  IL23R  RandomForestRegressor  1.220286  0.952714        0             MXL
# 5  IL23R                    SVR  1.169002  0.894614        0             MXL
# 6  IL23R       LinearRegression  0.757834  0.604942        0             PEL
# 7  IL23R  RandomForestRegressor  0.791924  0.629035        0             PEL
# 8  IL23R                    SVR  0.773807  0.629009        0             PEL
# 9  IL23R       LinearRegression  1.216319  1.001881        0             PUR
#
#       approach pair
# 0  CP-ALS(k=5)  CLM
# 1  CP-ALS(k=5)  CLM
# 2  CP-ALS(k=5)  CLM
# 3  CP-ALS(k=5)  MXL
# 4  CP-ALS(k=5)  MXL
# 5  CP-ALS(k=5)  MXL
# 6  CP-ALS(k=5)  PEL
# 7  CP-ALS(k=5)  PEL
# 8  CP-ALS(k=5)  PEL
# 9  CP-ALS(k=5)  PUR
#
# Data summary by cluster and model:
#                                rmse                  mae
#                               count   mean    std   mean    std
# cluster model
# 0       LinearRegression          4  1.071  0.224  0.854  0.174
#         RandomForestRegressor     4  1.056  0.195  0.847  0.157
#         SVR                       4  1.024  0.179  0.822  0.133
# 1       LinearRegression          5  1.037  0.036  0.929  0.042
#         RandomForestRegressor     5  1.020  0.039  0.920  0.044
#         SVR                       5  1.019  0.016  0.909  0.027
# 2       LinearRegression          5  1.047  0.081  0.921  0.086
#         RandomForestRegressor     5  1.020  0.071  0.899  0.082
#         SVR                       5  1.036  0.073  0.899  0.081
# 3       LinearRegression          7  1.026  0.131  0.842  0.099
#         RandomForestRegressor     7  1.023  0.130  0.837  0.111
#         SVR                       7  1.033  0.127  0.842  0.110
# 4       LinearRegression          4  1.061  0.131  0.845  0.091
#         RandomForestRegressor     4  1.032  0.094  0.817  0.060
#         SVR                       4  1.038  0.098  0.817  0.064
#
# Overall summary by model:
#                        rmse                  mae
#                       count   mean    std   mean    std
# model
# LinearRegression         25  1.045  0.119  0.878  0.102
# RandomForestRegressor    25  1.029  0.107  0.864  0.098
# SVR                      25  1.030  0.101  0.860  0.092
